# %% [markdown]
# ### 특정 거리의 도시 찾기

# %% [markdown]
# [백준 링크](https://www.acmicpc.net/problem/18352) []

# %% [markdown]
# + 어떤 나라에는 1 ~ N번까지의 도시와 M개의 단방향 도로 존재
# + 모든 도로의 거리는 1
# + 특정한 도시 X로부터 출발하여 도달할 수 있는 모든 도시 중에서,
#   최단 거리가 정확히 K인 모든 도시의 번호를 출력하는 프로그램 작성하기
# <br>
#
# + 또한 출발 도시 X에서 출발 도시 X로 가는 최단 거리는 항상 0이라고 가정
# <br>
#
# **예시**
# + N = 4, K = 2, X = 1일 때 다음과 같이 그래프가 구성되어 있다고 가정

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# + 이때 1번 도시에서 출발하여 도달할 수 있는 도시 중에서, 최단 거리가 2인 도시는 4번 도시 뿐
# + 2번과 3번 도시의 경우, 최단 거리가 1이기 때문에 출력 X
# <br>
#
# **입력 조건**
# + 첫째 줄에 도시의 개수 N, 도로의 개수 M, 거리 정보 K, 출발 도시의 번호 X가 주어짐
#   (2 <= N <= 300,000, 1 <= M <= 1,000,000, 1 <= K <= 300,000, 1 <= X <= N)
# + 둘째 줄부터 M개의 줄에 걸쳐서 두 개의 자연수 A, B가 주어지며, 각 자연수는 공백으로 구분
#   -> 이는 A번 도시에서 B번 도시로 이동하는 단방향 도로가 존재한다는 의미 (1 <= A,B <= N)
#   단, A와 B는 서로 다른 자연수
#
# **출력 조건**
# + X로부터 출발하여 도달할 수 있는 도시 중에서, 최단 거리가 K인 모든 도시의 번호를 한 줄에 하나씩 오름차순으로 출력
# + 이 때 도달할 수 있는 도시 중에서, 최단 거리가 K인 도시가 하나도 존재하지 않으면 -1 출력
#
# **입력 예시 1**
# 4 4 2 1
# 1 2
# 1 3
# 2 3
# 2 4
#
# **출력 예시 1**
# 4
#
# **입력 예시 2**
# 4 3 2 1
# 1 2
# 1 3
# 1 4
#
# **출력 예시 2**
# -1
#
# **입력 예시 3**
# 4 4 1 1
# 1 2
# 1 3
# 2 3
# 2 4
#
# **출력 예시 3**
# 2
# 3

# %%
n, m, k, x = map(int, input().split())
graph = [[] for _ in range(n+1)]

for _ in range(m):
    a, b = map(int, input().split())
    graph[a].append(b)
graph
# Out:
# 4 4 1 1
# 1 2
# 1 3
# 2 3
# 2 4
# [[], [2, 3], [3, 4], [], []]

# %%
distance = [-1] * (n+1) # 모든 도시에 대해 최단 거리 초기화
distance[x] = 0 # 출발 도시 거리 = 0

distance
# Out:
# [-1, 0, -1, -1, -1]

# %%
from collections import deque

# 새로운 큐 만들기
q = deque([x])

while q:
    now = q.popleft()
    # 지금 도시에서 도로 있는 모든 도시 돌면서 확인
    for next_node in graph[now]:
        # 만약에 거리가 -1이면(아직 방문 X라면)
        if distance[next_node] == -1:
            distance[next_node] = distance[now] + 1 # 최단거리 갱신해주기
            q.append(next_node) # 다음에 방문할 위치

# 일단 체크 False로 두고 거리 K와 꼭 맞는게 있다면 출력해주고 트루로 바꿔주기
check = False
for i in range(1, n+1):
    if distance[i] == k:
        print(i)
        check = True

# 다 진행했는데도 아직 False면 K와 같은 거리가 없는거니까 -1 출력
if check == False:
    print(-1)
# Out:
# 2
# 3

# %%
# 1번에서 출발해서 거리 2인 도시
n, m, k, x = map(int, input().split())
graph = [[] for _ in range(n+1)]

for _ in range(m):
    a, b = map(int, input().split())
    graph[a].append(b)

distance = [-1] * (n+1) # 모든 도시에 대해 최단 거리 초기화
distance[x] = 0 # 출발 도시 거리 = 0

from collections import deque

# 새로운 큐 만들기
q = deque([x])

while q:
    now = q.popleft()
    # 지금 도시에서 도로 있는 모든 도시 돌면서 확인
    for next_node in graph[now]:
        # 만약에 거리가 -1이면(아직 방문 X라면)
        if distance[next_node] == -1:
            distance[next_node] = distance[now] + 1 # 최단거리 갱신해주기
            q.append(next_node) # 다음에 방문할 위치

# 일단 체크 False로 두고 거리 K와 꼭 맞는게 있다면 출력해주고 트루로 바꿔주기
check = False
for i in range(1, n+1):
    if distance[i] == k:
        print(i)
        check = True

# 다 진행했는데도 아직 False면 K와 같은 거리가 없는거니까 -1 출력
if check == False:
    print(-1)
# Out:
# 4 4 2 1
# 1 2
# 1 3
# 2 3
# 2 4
# 4

# %%
# 1번에서 출발해서 거리 2인 도시
n, m, k, x = map(int, input().split())
graph = [[] for _ in range(n+1)]

for _ in range(m):
    a, b = map(int, input().split())
    graph[a].append(b)

distance = [-1] * (n+1) # 모든 도시에 대해 최단 거리 초기화
distance[x] = 0 # 출발 도시 거리 = 0

from collections import deque

# 새로운 큐 만들기
q = deque([x])

while q:
    now = q.popleft()
    # 지금 도시에서 도로 있는 모든 도시 돌면서 확인
    for next_node in graph[now]:
        # 만약에 거리가 -1이면(아직 방문 X라면)
        if distance[next_node] == -1:
            distance[next_node] = distance[now] + 1 # 최단거리 갱신해주기
            q.append(next_node) # 다음에 방문할 위치

# 일단 체크 False로 두고 거리 K와 꼭 맞는게 있다면 출력해주고 트루로 바꿔주기
check = False
for i in range(1, n+1):
    if distance[i] == k:
        print(i)
        check = True

# 다 진행했는데도 아직 False면 K와 같은 거리가 없는거니까 -1 출력
if check == False:
    print(-1)
# Out:
# 4 3 2 1
# 1 2
# 1 3
# 1 4
# -1

# %%
# 1번에서 출발해서 거리 1인 도시
n, m, k, x = map(int, input().split())
graph = [[] for _ in range(n+1)]

for _ in range(m):
    a, b = map(int, input().split())
    graph[a].append(b)

distance = [-1] * (n+1) # 모든 도시에 대해 최단 거리 초기화
distance[x] = 0 # 출발 도시 거리 = 0

from collections import deque

# 새로운 큐 만들기
q = deque([x])

while q:
    now = q.popleft()
    # 지금 도시에서 도로 있는 모든 도시 돌면서 확인
    for next_node in graph[now]:
        # 만약에 거리가 -1이면(아직 방문 X라면)
        if distance[next_node] == -1:
            distance[next_node] = distance[now] + 1 # 최단거리 갱신해주기
            q.append(next_node) # 다음에 방문할 위치

# 일단 체크 False로 두고 거리 K와 꼭 맞는게 있다면 출력해주고 트루로 바꿔주기
check = False
for i in range(1, n+1):
    if distance[i] == k:
        print(i)
        check = True

# 다 진행했는데도 아직 False면 K와 같은 거리가 없는거니까 -1 출력
if check == False:
    print(-1)
# Out:
# 4 4 1 1
# 1 2
# 1 3
# 2 3
# 2 4
# 2
# 3
